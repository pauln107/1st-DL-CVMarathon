# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 使用 colab 環境的同學請執行以下程式碼
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
# import tensorflow as tf
# print(tf.__version__)

# import os
# from google.colab import drive 
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# os.system("mkdir cupoy_cv_part4") # 可以自己改路徑
# %cd cupoy_cv_part4 # 可以自己改路徑

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# Out:
# Using TensorFlow backend.

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:From C:\Users\fisheden\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\fisheden\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# 印出網路結構
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 94, 94, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 47, 47, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 32)        4640
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1049088
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 1,424,286
# Trainable params: 1,424,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# WARNING:tensorflow:From C:\Users\fisheden\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 1712 samples, validate on 428 samples
# Epoch 1/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0083 - val_loss: 0.0025
#
# Epoch 00001: val_loss improved from inf to 0.00248, saving model to best_weights.h5
# Epoch 2/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0019 - val_loss: 0.0020
#
# Epoch 00002: val_loss improved from 0.00248 to 0.00201, saving model to best_weights.h5
# Epoch 3/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0014 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00201
# Epoch 4/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00201 to 0.00190, saving model to best_weights.h5
# Epoch 5/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0012 - val_loss: 0.0019
#
# Epoch 00005: val_loss did not improve from 0.00190
# Epoch 6/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 0.0011 - val_loss: 0.0019
#
# Epoch 00006: val_loss improved from 0.00190 to 0.00188, saving model to best_weights.h5
# Epoch 7/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.8921e-04 - val_loss: 0.0018
#
# Epoch 00007: val_loss improved from 0.00188 to 0.00177, saving model to best_weights.h5
# Epoch 8/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.8212e-04 - val_loss: 0.0017
#
# Epoch 00008: val_loss improved from 0.00177 to 0.00170, saving model to best_weights.h5
# Epoch 9/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 7.5313e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss improved from 0.00170 to 0.00150, saving model to best_weights.h5
# Epoch 10/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 6.8680e-04 - val_loss: 0.0014
#
# Epoch 00010: val_loss improved from 0.00150 to 0.00137, saving model to best_weights.h5
# Epoch 11/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 6.2368e-04 - val_loss: 0.0013
#
# Epoch 00011: val_loss improved from 0.00137 to 0.00131, saving model to best_weights.h5
# Epoch 12/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 5.5399e-04 - val_loss: 0.0012
#
# Epoch 00012: val_loss improved from 0.00131 to 0.00124, saving model to best_weights.h5
# Epoch 13/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 5.0666e-04 - val_loss: 0.0011
#
# Epoch 00013: val_loss improved from 0.00124 to 0.00115, saving model to best_weights.h5
# Epoch 14/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.7499e-04 - val_loss: 0.0011
#
# Epoch 00014: val_loss improved from 0.00115 to 0.00111, saving model to best_weights.h5
# Epoch 15/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.5360e-04 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00111
# Epoch 16/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 4.2139e-04 - val_loss: 0.0010
#
# Epoch 00016: val_loss improved from 0.00111 to 0.00104, saving model to best_weights.h5
# Epoch 17/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.9348e-04 - val_loss: 0.0010
#
# Epoch 00017: val_loss improved from 0.00104 to 0.00102, saving model to best_weights.h5
# Epoch 18/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.8639e-04 - val_loss: 9.7591e-04
#
# Epoch 00018: val_loss improved from 0.00102 to 0.00098, saving model to best_weights.h5
# Epoch 19/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.7251e-04 - val_loss: 0.0010
#
# Epoch 00019: val_loss did not improve from 0.00098
# Epoch 20/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.5554e-04 - val_loss: 0.0010
#
# Epoch 00020: val_loss did not improve from 0.00098
# Epoch 21/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.3913e-04 - val_loss: 9.1388e-04
#
# Epoch 00021: val_loss improved from 0.00098 to 0.00091, saving model to best_weights.h5
# Epoch 22/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.3624e-04 - val_loss: 9.5980e-04
#
# Epoch 00022: val_loss did not improve from 0.00091
# Epoch 23/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.2725e-04 - val_loss: 9.0484e-04
#
# Epoch 00023: val_loss improved from 0.00091 to 0.00090, saving model to best_weights.h5
# Epoch 24/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.1186e-04 - val_loss: 9.0139e-04
#
# Epoch 00024: val_loss improved from 0.00090 to 0.00090, saving model to best_weights.h5
# Epoch 25/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 3.0590e-04 - val_loss: 9.2095e-04
#
# Epoch 00025: val_loss did not improve from 0.00090
# Epoch 26/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.9745e-04 - val_loss: 9.0697e-04
#
# Epoch 00026: val_loss did not improve from 0.00090
# Epoch 27/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.8242e-04 - val_loss: 8.6744e-04
#
# Epoch 00027: val_loss improved from 0.00090 to 0.00087, saving model to best_weights.h5
# Epoch 28/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.7751e-04 - val_loss: 8.9146e-04
#
# Epoch 00028: val_loss did not improve from 0.00087
# Epoch 29/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.7143e-04 - val_loss: 8.7129e-04
#
# Epoch 00029: val_loss did not improve from 0.00087
# Epoch 30/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6400e-04 - val_loss: 8.5402e-04
#
# Epoch 00030: val_loss improved from 0.00087 to 0.00085, saving model to best_weights.h5
# Epoch 31/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.6375e-04 - val_loss: 8.2509e-04
#
# Epoch 00031: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 32/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.5041e-04 - val_loss: 8.3037e-04
#
# Epoch 00032: val_loss did not improve from 0.00083
# Epoch 33/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.5414e-04 - val_loss: 8.3742e-04
#
# Epoch 00033: val_loss did not improve from 0.00083
# Epoch 34/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4723e-04 - val_loss: 8.9211e-04
#
# Epoch 00034: val_loss did not improve from 0.00083
# Epoch 35/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.4165e-04 - val_loss: 8.4474e-04
#
# Epoch 00035: val_loss did not improve from 0.00083
# Epoch 36/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3578e-04 - val_loss: 8.3936e-04
#
# Epoch 00036: val_loss did not improve from 0.00083
# Epoch 37/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.3046e-04 - val_loss: 8.1510e-04
#
# Epoch 00037: val_loss improved from 0.00083 to 0.00082, saving model to best_weights.h5
# Epoch 38/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2969e-04 - val_loss: 8.0691e-04
#
# Epoch 00038: val_loss improved from 0.00082 to 0.00081, saving model to best_weights.h5
# Epoch 39/150
# 1712/1712 [==============================] - 8s 5ms/step - loss: 2.2338e-04 - val_loss: 8.4849e-04
#
# Epoch 00039: val_loss did not improve from 0.00081
# Epoch 40/150
# 1712/1712 [==============================] - 8s 4ms/step - loss: 2.1465e-04 - val_loss: 8.5245e-04
#
# Epoch 00040: val_loss did not improve from 0.00081
# Epoch 41/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1992e-04 - val_loss: 8.4459e-04
#
# Epoch 00041: val_loss did not improve from 0.00081
# Epoch 42/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1918e-04 - val_loss: 7.9890e-04
#
# Epoch 00042: val_loss improved from 0.00081 to 0.00080, saving model to best_weights.h5
# Epoch 43/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.2005e-04 - val_loss: 8.5661e-04
#
# Epoch 00043: val_loss did not improve from 0.00080
# Epoch 44/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.1032e-04 - val_loss: 7.9576e-04
#
# Epoch 00044: val_loss improved from 0.00080 to 0.00080, saving model to best_weights.h5
# Epoch 45/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0857e-04 - val_loss: 8.6200e-04
#
# Epoch 00045: val_loss did not improve from 0.00080
# Epoch 46/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 2.0639e-04 - val_loss: 8.2203e-04
#
# Epoch 00046: val_loss did not improve from 0.00080
# Epoch 47/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9516e-04 - val_loss: 7.8898e-04
#
# Epoch 00047: val_loss improved from 0.00080 to 0.00079, saving model to best_weights.h5
# Epoch 48/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9590e-04 - val_loss: 7.8217e-04
#
# Epoch 00048: val_loss improved from 0.00079 to 0.00078, saving model to best_weights.h5
# Epoch 49/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9412e-04 - val_loss: 8.0278e-04
#
# Epoch 00049: val_loss did not improve from 0.00078
# Epoch 50/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9410e-04 - val_loss: 7.8209e-04
#
# Epoch 00050: val_loss improved from 0.00078 to 0.00078, saving model to best_weights.h5
# Epoch 51/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9831e-04 - val_loss: 7.9592e-04
#
# Epoch 00051: val_loss did not improve from 0.00078
# Epoch 52/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.9117e-04 - val_loss: 8.4821e-04
#
# Epoch 00052: val_loss did not improve from 0.00078
# Epoch 53/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8709e-04 - val_loss: 8.4099e-04
#
# Epoch 00053: val_loss did not improve from 0.00078
# Epoch 54/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8391e-04 - val_loss: 7.9564e-04
#
# Epoch 00054: val_loss did not improve from 0.00078
# Epoch 55/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8178e-04 - val_loss: 7.9093e-04
#
# Epoch 00055: val_loss did not improve from 0.00078
# Epoch 56/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8299e-04 - val_loss: 7.8763e-04
#
# Epoch 00056: val_loss did not improve from 0.00078
# Epoch 57/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.8262e-04 - val_loss: 8.1497e-04
#
# Epoch 00057: val_loss did not improve from 0.00078
# Epoch 58/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7762e-04 - val_loss: 8.0303e-04
#
# Epoch 00058: val_loss did not improve from 0.00078
# Epoch 59/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7268e-04 - val_loss: 7.5965e-04
#
# Epoch 00059: val_loss improved from 0.00078 to 0.00076, saving model to best_weights.h5
# Epoch 60/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7268e-04 - val_loss: 7.9269e-04
#
# Epoch 00060: val_loss did not improve from 0.00076
# Epoch 61/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7909e-04 - val_loss: 8.4987e-04
#
# Epoch 00061: val_loss did not improve from 0.00076
# Epoch 62/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.7050e-04 - val_loss: 8.3870e-04
#
# Epoch 00062: val_loss did not improve from 0.00076
# Epoch 63/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6553e-04 - val_loss: 7.8760e-04
#
# Epoch 00063: val_loss did not improve from 0.00076
# Epoch 64/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6850e-04 - val_loss: 7.7273e-04
#
# Epoch 00064: val_loss did not improve from 0.00076
# Epoch 65/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6321e-04 - val_loss: 7.7848e-04
#
# Epoch 00065: val_loss did not improve from 0.00076
# Epoch 66/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6620e-04 - val_loss: 7.8484e-04
#
# Epoch 00066: val_loss did not improve from 0.00076
# Epoch 67/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6256e-04 - val_loss: 7.8186e-04
#
# Epoch 00067: val_loss did not improve from 0.00076
# Epoch 68/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.6074e-04 - val_loss: 7.7462e-04
#
# Epoch 00068: val_loss did not improve from 0.00076
# Epoch 69/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5850e-04 - val_loss: 8.1099e-04
#
# Epoch 00069: val_loss did not improve from 0.00076
# Epoch 70/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5576e-04 - val_loss: 7.8413e-04
#
# Epoch 00070: val_loss did not improve from 0.00076
# Epoch 71/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5403e-04 - val_loss: 7.8719e-04
#
# Epoch 00071: val_loss did not improve from 0.00076
# Epoch 72/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.5402e-04 - val_loss: 7.9396e-04
#
# Epoch 00072: val_loss did not improve from 0.00076
# Epoch 73/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4983e-04 - val_loss: 8.2798e-04
#
# Epoch 00073: val_loss did not improve from 0.00076
# Epoch 74/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4652e-04 - val_loss: 7.8755e-04
#
# Epoch 00074: val_loss did not improve from 0.00076
# Epoch 75/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4751e-04 - val_loss: 7.9153e-04
#
# Epoch 00075: val_loss did not improve from 0.00076
# Epoch 76/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4586e-04 - val_loss: 8.2750e-04
#
# Epoch 00076: val_loss did not improve from 0.00076
# Epoch 77/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4763e-04 - val_loss: 7.6583e-04
#
# Epoch 00077: val_loss did not improve from 0.00076
# Epoch 78/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4826e-04 - val_loss: 7.6765e-04
#
# Epoch 00078: val_loss did not improve from 0.00076
# Epoch 79/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3953e-04 - val_loss: 8.1300e-04
#
# Epoch 00079: val_loss did not improve from 0.00076
# Epoch 80/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4624e-04 - val_loss: 7.7196e-04
#
# Epoch 00080: val_loss did not improve from 0.00076
# Epoch 81/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4209e-04 - val_loss: 7.6865e-04
#
# Epoch 00081: val_loss did not improve from 0.00076
# Epoch 82/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3731e-04 - val_loss: 7.5779e-04
#
# Epoch 00082: val_loss improved from 0.00076 to 0.00076, saving model to best_weights.h5
# Epoch 83/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4455e-04 - val_loss: 7.6874e-04
#
# Epoch 00083: val_loss did not improve from 0.00076
# Epoch 84/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.4051e-04 - val_loss: 8.1338e-04
#
# Epoch 00084: val_loss did not improve from 0.00076
# Epoch 85/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3542e-04 - val_loss: 8.0616e-04
#
# Epoch 00085: val_loss did not improve from 0.00076
# Epoch 86/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3515e-04 - val_loss: 8.0944e-04
#
# Epoch 00086: val_loss did not improve from 0.00076
# Epoch 87/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3460e-04 - val_loss: 7.7830e-04
#
# Epoch 00087: val_loss did not improve from 0.00076
# Epoch 88/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3270e-04 - val_loss: 8.0436e-04
#
# Epoch 00088: val_loss did not improve from 0.00076
# Epoch 89/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3318e-04 - val_loss: 8.2175e-04
#
# Epoch 00089: val_loss did not improve from 0.00076
# Epoch 90/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3163e-04 - val_loss: 8.0508e-04
#
# Epoch 00090: val_loss did not improve from 0.00076
# Epoch 91/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2958e-04 - val_loss: 8.4196e-04
#
# Epoch 00091: val_loss did not improve from 0.00076
# Epoch 92/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3263e-04 - val_loss: 7.8134e-04
#
# Epoch 00092: val_loss did not improve from 0.00076
# Epoch 93/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3317e-04 - val_loss: 7.6587e-04
#
# Epoch 00093: val_loss did not improve from 0.00076
# Epoch 94/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2715e-04 - val_loss: 7.8905e-04
#
# Epoch 00094: val_loss did not improve from 0.00076
# Epoch 95/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.3281e-04 - val_loss: 8.0934e-04
#
# Epoch 00095: val_loss did not improve from 0.00076
# Epoch 96/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2822e-04 - val_loss: 8.0473e-04
#
# Epoch 00096: val_loss did not improve from 0.00076
# Epoch 97/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2403e-04 - val_loss: 7.6902e-04
#
# Epoch 00097: val_loss did not improve from 0.00076
# Epoch 98/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2745e-04 - val_loss: 7.8376e-04
#
# Epoch 00098: val_loss did not improve from 0.00076
# Epoch 99/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2295e-04 - val_loss: 7.5975e-04
#
# Epoch 00099: val_loss did not improve from 0.00076
# Epoch 100/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2520e-04 - val_loss: 7.6555e-04
#
# Epoch 00100: val_loss did not improve from 0.00076
# Epoch 101/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.2046e-04 - val_loss: 7.8500e-04
#
# Epoch 00101: val_loss did not improve from 0.00076
# Epoch 102/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1939e-04 - val_loss: 7.9283e-04
#
# Epoch 00102: val_loss did not improve from 0.00076
# Epoch 103/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1775e-04 - val_loss: 7.5049e-04
#
# Epoch 00103: val_loss improved from 0.00076 to 0.00075, saving model to best_weights.h5
# Epoch 104/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1705e-04 - val_loss: 7.8445e-04
#
# Epoch 00104: val_loss did not improve from 0.00075
# Epoch 105/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1883e-04 - val_loss: 7.6923e-04
#
# Epoch 00105: val_loss did not improve from 0.00075
# Epoch 106/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1947e-04 - val_loss: 7.9736e-04
#
# Epoch 00106: val_loss did not improve from 0.00075
# Epoch 107/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1887e-04 - val_loss: 7.8725e-04
#
# Epoch 00107: val_loss did not improve from 0.00075
# Epoch 108/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1440e-04 - val_loss: 7.8614e-04
#
# Epoch 00108: val_loss did not improve from 0.00075
# Epoch 109/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1311e-04 - val_loss: 7.8486e-04
#
# Epoch 00109: val_loss did not improve from 0.00075
# Epoch 110/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1415e-04 - val_loss: 8.0181e-04
#
# Epoch 00110: val_loss did not improve from 0.00075
# Epoch 111/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1650e-04 - val_loss: 7.9925e-04
#
# Epoch 00111: val_loss did not improve from 0.00075
# Epoch 112/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1527e-04 - val_loss: 7.9044e-04
#
# Epoch 00112: val_loss did not improve from 0.00075
# Epoch 113/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1524e-04 - val_loss: 8.5116e-04
#
# Epoch 00113: val_loss did not improve from 0.00075
# Epoch 114/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1335e-04 - val_loss: 7.9378e-04
#
# Epoch 00114: val_loss did not improve from 0.00075
# Epoch 115/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1477e-04 - val_loss: 8.0093e-04
#
# Epoch 00115: val_loss did not improve from 0.00075
# Epoch 116/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1610e-04 - val_loss: 7.8385e-04
#
# Epoch 00116: val_loss did not improve from 0.00075
# Epoch 117/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1189e-04 - val_loss: 8.1076e-04
#
# Epoch 00117: val_loss did not improve from 0.00075
# Epoch 118/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.1005e-04 - val_loss: 7.7220e-04
#
# Epoch 00118: val_loss did not improve from 0.00075
# Epoch 119/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0737e-04 - val_loss: 7.7896e-04
#
# Epoch 00119: val_loss did not improve from 0.00075
# Epoch 120/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0521e-04 - val_loss: 7.7532e-04
#
# Epoch 00120: val_loss did not improve from 0.00075
# Epoch 121/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0550e-04 - val_loss: 7.8281e-04
#
# Epoch 00121: val_loss did not improve from 0.00075
# Epoch 122/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0349e-04 - val_loss: 7.8240e-04
#
# Epoch 00122: val_loss did not improve from 0.00075
# Epoch 123/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0623e-04 - val_loss: 7.8229e-04
#
# Epoch 00123: val_loss did not improve from 0.00075
# Epoch 124/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0324e-04 - val_loss: 7.6346e-04
#
# Epoch 00124: val_loss did not improve from 0.00075
# Epoch 125/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0245e-04 - val_loss: 8.0058e-04
#
# Epoch 00125: val_loss did not improve from 0.00075
# Epoch 126/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0546e-04 - val_loss: 8.0392e-04
#
# Epoch 00126: val_loss did not improve from 0.00075
# Epoch 127/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0292e-04 - val_loss: 7.8823e-04
#
# Epoch 00127: val_loss did not improve from 0.00075
# Epoch 128/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0444e-04 - val_loss: 7.6899e-04
#
# Epoch 00128: val_loss did not improve from 0.00075
# Epoch 129/150
# 1712/1712 [==============================] - 9s 5ms/step - loss: 1.0153e-04 - val_loss: 7.8446e-04
#
# Epoch 00129: val_loss did not improve from 0.00075
# Epoch 130/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9930e-05 - val_loss: 7.9032e-04
#
# Epoch 00130: val_loss did not improve from 0.00075
# Epoch 131/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7539e-05 - val_loss: 8.0260e-04
#
# Epoch 00131: val_loss did not improve from 0.00075
# Epoch 132/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0003e-04 - val_loss: 8.1646e-04
#
# Epoch 00132: val_loss did not improve from 0.00075
# Epoch 133/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 1.0143e-04 - val_loss: 7.8572e-04
#
# Epoch 00133: val_loss did not improve from 0.00075
# Epoch 134/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9938e-05 - val_loss: 7.9247e-04
#
# Epoch 00134: val_loss did not improve from 0.00075
# Epoch 135/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9946e-05 - val_loss: 7.7894e-04
#
# Epoch 00135: val_loss did not improve from 0.00075
# Epoch 136/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.9164e-05 - val_loss: 7.9850e-04
#
# Epoch 00136: val_loss did not improve from 0.00075
# Epoch 137/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7795e-05 - val_loss: 7.9797e-04
#
# Epoch 00137: val_loss did not improve from 0.00075
# Epoch 138/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.7930e-05 - val_loss: 7.8381e-04
#
# Epoch 00138: val_loss did not improve from 0.00075
# Epoch 139/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.6281e-05 - val_loss: 7.9169e-04
#
# Epoch 00139: val_loss did not improve from 0.00075
# Epoch 140/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4032e-05 - val_loss: 7.9599e-04
#
# Epoch 00140: val_loss did not improve from 0.00075
# Epoch 141/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.2980e-05 - val_loss: 8.2189e-04
#
# Epoch 00141: val_loss did not improve from 0.00075
# Epoch 142/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.4614e-05 - val_loss: 7.6530e-04
#
# Epoch 00142: val_loss did not improve from 0.00075
# Epoch 143/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3049e-05 - val_loss: 8.0992e-04
# Epoch 00143: val_loss did not improve from 0.00075
# Epoch 144/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.5755e-05 - val_loss: 8.0688e-04
#
# Epoch 00144: val_loss did not improve from 0.00075
# Epoch 145/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0704e-05 - val_loss: 7.9167e-04
#
# Epoch 00145: val_loss did not improve from 0.00075
# Epoch 146/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.3833e-05 - val_loss: 7.7937e-04
#
# Epoch 00146: val_loss did not improve from 0.00075
# Epoch 147/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.0201e-05 - val_loss: 7.9173e-04
#
# Epoch 00147: val_loss did not improve from 0.00075
# Epoch 148/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1813e-05 - val_loss: 7.8547e-04
#
# Epoch 00148: val_loss did not improve from 0.00075
# Epoch 149/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 8.7952e-05 - val_loss: 7.8319e-04
#
# Epoch 00149: val_loss did not improve from 0.00075
# Epoch 150/150
# 1712/1712 [==============================] - 7s 4ms/step - loss: 9.1104e-05 - val_loss: 7.9637e-04
#
# Epoch 00150: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Your code
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=40,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.2)

train_X = imgs_train.reshape(-1, 96, 96, 1)
training_set = train_datagen.flow(train_X, points_train,batch_size = 32)

# %%
checkpoint_aug = ModelCheckpoint('best_weights_augment.h5', verbose=1, save_best_only=True)

hist_model_aug = model_with_augment.fit_generator(training_set, steps_per_epoch = len(train_X) // 32, 
                                                  nb_epoch = 20, callbacks=[checkpoint, hist],
                                                  shuffle=True, validation_data=(train_X, points_train))
# Out:
# C:\Users\fisheden\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   """
# C:\Users\fisheden\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras.pre..., steps_per_epoch=66, callbacks=[<keras.ca..., shuffle=True, validation_data=(array([[[..., epochs=20)`
#   """
# Epoch 1/20
# 66/66 [==============================] - 12s 186ms/step - loss: 0.0045 - val_loss: 0.0012
#
# Epoch 00001: val_loss did not improve from 0.00075
# Epoch 2/20
# 66/66 [==============================] - 12s 177ms/step - loss: 0.0015 - val_loss: 0.0011
#
# Epoch 00002: val_loss did not improve from 0.00075
# Epoch 3/20
# 66/66 [==============================] - 12s 177ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00003: val_loss did not improve from 0.00075
# Epoch 4/20
# 66/66 [==============================] - 11s 171ms/step - loss: 0.0013 - val_loss: 0.0011
#
# Epoch 00004: val_loss did not improve from 0.00075
# Epoch 5/20
# 66/66 [==============================] - 12s 181ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00005: val_loss did not improve from 0.00075
# Epoch 6/20
# 66/66 [==============================] - 11s 173ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00006: val_loss did not improve from 0.00075
# Epoch 7/20
# 66/66 [==============================] - 11s 170ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00007: val_loss did not improve from 0.00075
# Epoch 8/20
# 66/66 [==============================] - 11s 168ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00008: val_loss did not improve from 0.00075
# Epoch 9/20
# 66/66 [==============================] - 11s 170ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00009: val_loss did not improve from 0.00075
# Epoch 10/20
# 66/66 [==============================] - 11s 168ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00010: val_loss did not improve from 0.00075
# Epoch 11/20
# 66/66 [==============================] - 11s 168ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00011: val_loss did not improve from 0.00075
# Epoch 12/20
# 66/66 [==============================] - 12s 174ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00012: val_loss did not improve from 0.00075
# Epoch 13/20
# 66/66 [==============================] - 12s 175ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00013: val_loss did not improve from 0.00075
# Epoch 14/20
# 66/66 [==============================] - 11s 172ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00014: val_loss did not improve from 0.00075
# Epoch 15/20
# 66/66 [==============================] - 11s 170ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00015: val_loss did not improve from 0.00075
# Epoch 16/20
# 66/66 [==============================] - 11s 168ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00016: val_loss did not improve from 0.00075
# Epoch 17/20
# 66/66 [==============================] - 11s 170ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00017: val_loss did not improve from 0.00075
# Epoch 18/20
# 66/66 [==============================] - 11s 169ms/step - loss: 0.0011 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00075
# Epoch 19/20
# 66/66 [==============================] - 11s 169ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00075
# Epoch 20/20
# 66/66 [==============================] - 11s 169ms/step - loss: 0.0012 - val_loss: 0.0011
#
# Epoch 00020: val_loss did not improve from 0.00075

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model_aug.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model_aug.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %%
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model_with_augment.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))
# Out:
# C:\Users\fisheden\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """
